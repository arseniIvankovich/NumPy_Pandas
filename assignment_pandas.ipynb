# %% [markdown]
# ## Датасет собран из базы данных переписи 1994 года и содержит данные о доходах.
# ### Информация о данных:
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, * Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * salary: >50K,<=50K
#
# ## Проведите анализ данных при помощи Pandas выполнив поставленные задачи.
# ####

# %%
import pandas as pd

# %%
# загружаем датасет
data = pd.read_csv("./data/adult.data.csv")
data.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 32556             0             0              38  United-States  <=50K
# ...

# %% [markdown]
# **1. Посчитайте, сколько мужчин и женщин (признак *sex*) представлено в этом датасете**

# %%
data['sex'].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %% [markdown]
# **2. Каков средний возраст мужчин (признак *age*) по всему датасету?**

# %%
male = data[data['sex'] == 'Male']
male['age'].mean()
# Out:
# 39.43354749885268

# %% [markdown]
# **3. Какова доля граждан Соединенных Штатов (признак *native-country*)?**

# %%
us_citizens = data[data['native-country'] == 'United-States'].shape[0]
all_citizens = data.shape[0]

us_citizens / all_citizens * 100
# Out:
# 89.5857006848684

# %% [markdown]
# **4-5. Рассчитайте среднее значение и среднеквадратичное отклонение возраста тех, кто получает более 50K в год (признак *salary*) и тех, кто получает менее 50K в год**

# %%
low_salary = data[data['salary'] == '<=50K']
high_salary = data[data['salary'] == '>50K']

mean_high_salary = high_salary['age'].mean()
std_high_salary = high_salary['age'].std()

mean_low_salary = low_salary['age'].mean()
std_low_salary = low_salary['age'].std()

print(f'mean of those who get more than 50k {mean_high_salary} and std {std_high_salary}')

print(f'mean of those who get more than 50k {mean_low_salary} and std {std_low_salary}')
# Out:
# mean of those who get more than 50k 36.78373786407767 and std 14.02008849082488
# mean of those who get more than 50k 44.24984058155847 and std 10.519027719851826

# %% [markdown]
# **6. Правда ли, что люди, которые получают больше 50k, имеют минимум высшее образование? (признак *education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters* или *Doctorate*)**

# %%
high_salary = data[data['salary'] == '>50K']
high_salary_and_high_edu = high_salary[~high_salary['education'].isin(['Bachelors', 'Prof-school', 'Assoc-acdm', 'Assoc-voc',
                                           'Masters','Doctorate'])]
if high_salary_and_high_edu.empty:
    print('there are people with salaries over 50K have a higher education.')
else:
    print('there are people with salaries over 50K who do not have a higher education.')
# Out:
# there are people with salaries over 50K who do not have a higher education.

# %% [markdown]
# **7. Выведите статистику возраста для каждой расы (признак *race*) и каждого пола. Используйте *groupby* и *describe*. Найдите таким образом максимальный возраст мужчин расы *Asian-Pac-Islander*.**

# %%
data.groupby(['sex','race'])['age'].describe()
# Out:
#                              count       mean        std   min   25%   50%  \
# sex    race
# Female Amer-Indian-Eskimo    119.0  37.117647  13.114991  17.0  27.0  36.0
#        Asian-Pac-Islander    346.0  35.089595  12.300845  17.0  25.0  33.0
#        Black                1555.0  37.854019  12.637197  17.0  28.0  37.0
#        Other                 109.0  31.678899  11.631599  17.0  23.0  29.0
#        White                8642.0  36.811618  14.329093  17.0  25.0  35.0
# Male   Amer-Indian-Eskimo    192.0  37.208333  12.049563  17.0  28.0  35.0
#        Asian-Pac-Islander    693.0  39.073593  12.883944  18.0  29.0  37.0
#        Black                1569.0  37.682600  12.882612  17.0  27.0  36.0
#        Other                 162.0  34.654321  11.355531  17.0  26.0  32.0
#        White               19174.0  39.652498  13.436029  17.0  29.0  38.0
#
#                              75%   max
# sex    race
# Female Amer-Indian-Eskimo  46.00  80.0
# ...

# %%
data[(data['race'] == 'Asian-Pac-Islander') & (data['sex'] == 'Male')]['age'].max()
# Out:
# 90

# %% [markdown]
# **8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак *marital-status*)? Женатыми считаем тех, у кого *marital-status* начинается с *Married* (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.**

# %%
married_with_high_salary = data[(data['sex'] == 'Male') & (data['salary'] == '>50K') & 
                                (data['marital-status'].isin(['BacheMarried-civ-spouselors', 'Married-spouse-absent',
                                                                                                  'Married-AF-spouse']))].shape[0]
all_with_high_salary = data[(data['sex'] == 'Male') & (data['salary'] == '>50K')].shape[0]

proportion = married_with_high_salary/all_with_high_salary
print(f'The procent of those earning a lot (>50K) among married men {proportion * 100}%')
print(f'The procent of those earning a lot (>50K) among not married men {(1-proportion) * 100}%')
# Out:
# The proportion of those earning a lot (>50K) among married men 0.40528369858901225%
# The proportion of those earning a lot (>50K) among not married men 99.59471630141098%

# %% [markdown]
# **9. Какое максимальное число часов человек работает в неделю (признак *hours-per-week*)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?**

# %%
max_hours = data['hours-per-week'].max()
people_with_max_hours = data[data['hours-per-week'] == max_hours].shape[0]
people_with_max_hours_and_high_salary = data[(data['hours-per-week'] == max_hours) &
                                             (data['salary'] == '>50K')].shape[0]

print(f'Max hours per week {max_hours}')
print(f'Amount of people work max hours per week {people_with_max_hours}')
print(f'Procent of people work max hours per week and have high income {people_with_max_hours_and_high_salary / people_with_max_hours*  100}%')
# Out:
# Max hours per week 99
# Amount of people work max hours per week 85
# Procent of people work max hours per week and have high income 29.411764705882355%

# %% [markdown]
# **10. Посчитайте среднее время работы (*hours-per-week*) зарабатывающих мало и много (*salary*) для каждой страны (*native-country*).**

# %%
data.groupby(['native-country', 'salary'])['hours-per-week'].mean().unstack().fillna(0)
# Out:
# salary                          <=50K       >50K
# native-country
# ?                           40.164760  45.547945
# Cambodia                    41.416667  40.000000
# Canada                      37.914634  45.641026
# China                       37.381818  38.900000
# Columbia                    38.684211  50.000000
# Cuba                        37.985714  42.440000
# Dominican-Republic          42.338235  47.000000
# Ecuador                     38.041667  48.750000
# El-Salvador                 36.030928  45.000000
# England                     40.483333  44.533333
# France                      41.058824  50.750000
# Germany                     39.139785  44.977273
# Greece                      41.809524  50.625000
# Guatemala                   39.360656  36.666667
# Haiti                       36.325000  42.750000
# Holand-Netherlands          40.000000   0.000000
# Honduras                    34.333333  60.000000
# Hong                        39.142857  45.000000
# ...

# %% [markdown]
# **11.Сгруппируйте людей по возрастным группам *young*, *adult*, *retiree*, где:**
# * *young* соответствует 16-35 лет
# * *adult* - 35-70 лет
# * *retiree* - 70-100 лет
#
# **Проставьте название соответсвтуещей группы для каждого человека в новой колонке AgeGroup**

# %%
def age_group(age : int) -> str:
    if 16 <= age <= 35:
        return 'young'
    elif 35 < age <= 70:
        return 'adult'
    elif 70 < age <= 100:
        return 'retiree'
    else:
        return 'unknown'

# %%
data['AgeGroup'] = data['age'].apply(age_group)
data.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary  \
# 32556             0             0              38  United-States  <=50K
# ...

# %% [markdown]
# **12-13. Определите количество зарабатывающих >50K в каждой из возрастных групп (колонка AgeGroup), а также выведите название возрастной группы, в которой чаще зарабатывают больше 50К (>50K)**

# %%
slary_count =  data[data['salary'] == '>50K'].groupby('AgeGroup').size()
slary_count
# Out:
# AgeGroup
# adult      6042
# retiree      94
# young      1705
# dtype: int64

# %%
slary_count.idxmax()
# Out:
# 'adult'

# %% [markdown]
# **14. Сгруппируйте людей по типу занятости (колонка occupation) и определите количество людей в каждой группе. После чего напишите функциюю фильтрации filter_func, которая будет возвращать только те группы, в которых средний возраст (колонка age) не больше 40 и в которых все работники отрабатывают более 5 часов в неделю (колонка hours-per-week)**

# %%
def filter_func(df):
    avg_age = df['age'].mean()
    min_hours = df['hours-per-week'].min()
    return avg_age <= 40 and min_hours >= 5

# %%
occupation_count = data.groupby('occupation').size()
# Out:
# occupation
# ?                    1843
# Adm-clerical         3770
# Armed-Forces            9
# Craft-repair         4099
# Exec-managerial      4066
# Farming-fishing       994
# Handlers-cleaners    1370
# Machine-op-inspct    2002
# Other-service        3295
# Priv-house-serv       149
# Prof-specialty       4140
# Protective-serv       649
# Sales                3650
# Tech-support          928
# Transport-moving     1597
# dtype: int64

# %%
data.groupby('occupation').filter(filter_func)
# Out:
#        age    workclass  fnlwgt     education  education-num  \
# 442     24  Federal-gov  191073       HS-grad              9
# 1300    29  Federal-gov  301010  Some-college             10
# 14613   39  Federal-gov  227597       HS-grad              9
# 16111   24  Federal-gov  287988     Bachelors             13
# 18034   34  Federal-gov  172716          12th              8
# 18644   23  Federal-gov  163870  Some-college             10
# 18769   30  Federal-gov   76313       HS-grad              9
# 25799   46  Federal-gov  344415       Masters             14
# 32316   23  Federal-gov  173851       HS-grad              9
#
#            marital-status    occupation    relationship                race  \
# 442         Never-married  Armed-Forces       Own-child               White
# 1300        Never-married  Armed-Forces   Not-in-family               Black
# 14613       Never-married  Armed-Forces   Not-in-family               White
# ...
